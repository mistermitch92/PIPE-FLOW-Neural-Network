# %%
import copy
 
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pandas as pd
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


rand_seed = 921220

# %%
#load the calculated theoretical data from the csv file into a pandas dataframe
Theoretical_data = pd.read_csv('Theory_data.csv')

#load the target values of the parameters into a pandas dataframe
Target_Values = pd.read_csv('Target_Data.csv')

#look at the first few rows of the data
display(Theoretical_data.head())

#look at the Given Values
display(Target_Values.head())
# Out:
#    Radius (m)  Aspect Ratio  Pressure Drop (Pa)  Pressure Gradient(Pa m^-1)  \
# 0     0.00025          10.0          75000000.0                1.500000e+10
# 1     0.00025          10.0          75000000.0                1.500000e+10
# 2     0.00025          10.0          75000000.0                1.500000e+10
# 3     0.00025          10.0          75000000.0                1.500000e+10
# 4     0.00025          10.0          75000000.0                1.500000e+10
#
#    Apparent Wall Shear Rate (s^-1)  Volumetric Flow Rate (m^3 s^-1)
# 0                         1.815769                     2.228284e-11
# 1                         1.754430                     2.153009e-11
# 2                         1.711131                     2.099874e-11
# 3                         1.678935                     2.060363e-11
# 4                         7.919400                     9.718566e-11
#    Slip Velocity Coefficient  Shear Thinning Index  \
# 0               5.000000e-11                   0.5
# 1               5.000000e-11                   0.5
# 2               5.000000e-11                   0.5
# 3               5.000000e-11                   0.5
# 4               5.000000e-11                   0.6
#
#    Shear Thinning Consistency (Pa s^n)  Volumetric Flow from Slip (m^3 s^-1)  \
# 0                           800.000000                          1.791690e-11
# 1                           966.666667                          1.791690e-11
# 2                          1133.333333                          1.791690e-11
# 3                          1300.000000                          1.791690e-11
# 4                           800.000000                          1.791690e-11
#
#    Volumetric Flow from Bulk Flow (m^3 s^-1)
# 0                               4.365947e-12
# 1                               3.613197e-12
# 2                               3.081845e-12
# 3                               2.686736e-12
# 4                               7.926876e-11

# %%
# Create a StandardScaler object
Xscaler = StandardScaler()
yscaler = StandardScaler()

#scale the data
Theoretical_data_scaled = Xscaler.fit_transform(Theoretical_data)
Target_Values_scaled = yscaler.fit_transform(Target_Values)

#split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(Theoretical_data_scaled, Target_Values_scaled, test_size=0.5, random_state=rand_seed)

#split the training data into training and validation data
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.5, random_state=rand_seed)

# %%
print(X_train.shape, "train samples", X_val.shape, "validation samples", X_test.shape, "test samples")
print(y_train.shape, "train samples", y_val.shape, "validation samples", y_test.shape, "test samples")
# Out:
# (18000, 6) train samples (18000, 6) validation samples (36000, 6) test samples
# (18000, 5) train samples (18000, 5) validation samples (36000, 5) test samples

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# Define the model architecture
model = keras.Sequential([
    layers.Dense(64, activation='gelu', input_shape=(6,)), # Input layer
    layers.Dense(64, activation='gelu'), # Hidden layer1
    layers.Dense(64, activation='gelu'), # Hidden layer2
    layers.Dense(5) # No activation function for the output layer (linear activation function
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_val, y_val))

# Evaluate the model
loss = model.evaluate(X_test, y_test)

# Make predictions
y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# 563/563 [==============================] - 4s 6ms/step - loss: 0.5322 - val_loss: 0.4712
# Epoch 2/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4647 - val_loss: 0.4556
# Epoch 3/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4486 - val_loss: 0.4413
# Epoch 4/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4367 - val_loss: 0.4305
# Epoch 5/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4263 - val_loss: 0.4222
# Epoch 6/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4136 - val_loss: 0.4078
# Epoch 7/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.4039 - val_loss: 0.4003
# Epoch 8/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3975 - val_loss: 0.3943
# Epoch 9/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3931 - val_loss: 0.3951
# Epoch 10/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3897 - val_loss: 0.3941
# Epoch 11/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3874 - val_loss: 0.3871
# Epoch 12/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3849 - val_loss: 0.3878
# Epoch 13/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3840 - val_loss: 0.3850
# Epoch 14/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3820 - val_loss: 0.3857
# Epoch 15/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3802 - val_loss: 0.3819
# Epoch 16/100
# 563/563 [==============================] - 4s 6ms/step - loss: 0.3794 - val_loss: 0.3868
# Epoch 17/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3790 - val_loss: 0.3837
# Epoch 18/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3773 - val_loss: 0.3818
# Epoch 19/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3770 - val_loss: 0.3819
# Epoch 20/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3750 - val_loss: 0.3801
# Epoch 21/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3748 - val_loss: 0.3810
# Epoch 22/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3741 - val_loss: 0.3772
# Epoch 23/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3728 - val_loss: 0.3747
# Epoch 24/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3709 - val_loss: 0.3742
# Epoch 25/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3714 - val_loss: 0.3750
# Epoch 26/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3701 - val_loss: 0.3743
# Epoch 27/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3694 - val_loss: 0.3750
# Epoch 28/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3674 - val_loss: 0.3697
# Epoch 29/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3664 - val_loss: 0.3756
# Epoch 30/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3657 - val_loss: 0.3698
# Epoch 31/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3644 - val_loss: 0.3694
# Epoch 32/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3639 - val_loss: 0.3668
# Epoch 33/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3632 - val_loss: 0.3647
# Epoch 34/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3619 - val_loss: 0.3657
# Epoch 35/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3611 - val_loss: 0.3659
# Epoch 36/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3599 - val_loss: 0.3616
# Epoch 37/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3585 - val_loss: 0.3661
# Epoch 38/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3581 - val_loss: 0.3609
# Epoch 39/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3570 - val_loss: 0.3606
# Epoch 40/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3565 - val_loss: 0.3602
# Epoch 41/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3554 - val_loss: 0.3594
# Epoch 42/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3545 - val_loss: 0.3588
# Epoch 43/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3540 - val_loss: 0.3538
# Epoch 44/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3525 - val_loss: 0.3521
# Epoch 45/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3510 - val_loss: 0.3553
# Epoch 46/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3498 - val_loss: 0.3482
# Epoch 47/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3476 - val_loss: 0.3504
# Epoch 48/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3467 - val_loss: 0.3525
# Epoch 49/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3459 - val_loss: 0.3501
# Epoch 50/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3447 - val_loss: 0.3468
# Epoch 51/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3434 - val_loss: 0.3456
# Epoch 52/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3423 - val_loss: 0.3421
# Epoch 53/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3422 - val_loss: 0.3444
# Epoch 54/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.3394 - val_loss: 0.3424
# Epoch 55/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3384 - val_loss: 0.3428
# Epoch 56/100
# 563/563 [==============================] - 3s 6ms/step - loss: 0.3385 - val_loss: 0.3399
# Epoch 57/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3389 - val_loss: 0.3419
# Epoch 58/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3372 - val_loss: 0.3381
# Epoch 59/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3368 - val_loss: 0.3385
# Epoch 60/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3351 - val_loss: 0.3353
# Epoch 61/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3340 - val_loss: 0.3390
# Epoch 62/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3349 - val_loss: 0.3346
# Epoch 63/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3327 - val_loss: 0.3348
# Epoch 64/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3321 - val_loss: 0.3371
# Epoch 65/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3316 - val_loss: 0.3347
# Epoch 66/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3311 - val_loss: 0.3303
# Epoch 67/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3305 - val_loss: 0.3351
# Epoch 68/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3295 - val_loss: 0.3308
# Epoch 69/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3302 - val_loss: 0.3313
# Epoch 70/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3279 - val_loss: 0.3343
# Epoch 71/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3286 - val_loss: 0.3278
# Epoch 72/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3267 - val_loss: 0.3288
# Epoch 73/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3266 - val_loss: 0.3277
# Epoch 74/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3259 - val_loss: 0.3264
# Epoch 75/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3253 - val_loss: 0.3257
# Epoch 76/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3251 - val_loss: 0.3290
# Epoch 77/100
# 563/563 [==============================] - 3s 4ms/step - loss: 0.3240 - val_loss: 0.3250
# Epoch 78/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3236 - val_loss: 0.3255
# Epoch 79/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3239 - val_loss: 0.3304
# Epoch 80/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3218 - val_loss: 0.3241
# Epoch 81/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3226 - val_loss: 0.3239
# Epoch 82/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3220 - val_loss: 0.3235
# Epoch 83/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3223 - val_loss: 0.3232
# Epoch 84/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3214 - val_loss: 0.3185
# Epoch 85/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3204 - val_loss: 0.3235
# Epoch 86/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3202 - val_loss: 0.3236
# Epoch 87/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3208 - val_loss: 0.3184
# Epoch 88/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3192 - val_loss: 0.3243
# Epoch 89/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3183 - val_loss: 0.3243
# Epoch 90/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3175 - val_loss: 0.3159
# Epoch 91/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3173 - val_loss: 0.3183
# Epoch 92/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3162 - val_loss: 0.3252
# Epoch 93/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3170 - val_loss: 0.3168
# Epoch 94/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3154 - val_loss: 0.3184
# Epoch 95/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3158 - val_loss: 0.3190
# Epoch 96/100
# 563/563 [==============================] - 3s 4ms/step - loss: 0.3150 - val_loss: 0.3131
# Epoch 97/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3141 - val_loss: 0.3194
# Epoch 98/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3144 - val_loss: 0.3167
# Epoch 99/100
# 563/563 [==============================] - 2s 4ms/step - loss: 0.3135 - val_loss: 0.3165
# Epoch 100/100
# 563/563 [==============================] - 3s 5ms/step - loss: 0.3135 - val_loss: 0.3129
# 1125/1125 [==============================] - 3s 3ms/step - loss: 0.3194
# 1125/1125 [==============================] - 3s 2ms/step

# %%
# Plot the loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#turn the scaled data back into the original data
X_test_df = Xscaler.inverse_transform(X_test)
y_test_df = yscaler.inverse_transform(y_test)
y_pred_df = yscaler.inverse_transform(y_pred)

print(X_test_df[:,4].size)
print(y_test_df[:,4].size)
# Out:
# 36000
# 36000

# %%
#plot the data
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,4], y_test_df[:,3], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,4], y_pred_df[:,3], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Wall Shear Rate (s^-1)')
plt.ylabel('Q from slip (m^3 s^-1)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,5], y_test_df[:,3], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,5], y_pred_df[:,3], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Q total (m^3 s^-1)')
plt.ylabel('Q from slip (m^3 s^-1)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
#plot the data
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,4], y_test_df[:,4], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,4], y_pred_df[:,4], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Wall Shear Rate (s^-1)')
plt.ylabel('Q bulk (m^3 s^-1)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
#plot the data
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,4], y_test_df[:,0], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,4], y_pred_df[:,0], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Wall Shear Rate (s^-1)')
plt.ylabel('Beta)')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
#plot the data
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,4], y_test_df[:,1], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,4], y_pred_df[:,1], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Wall Shear Rate (s^-1)')
plt.ylabel('n')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
#plot the data
plt.figure(figsize=(10, 10))
plt.scatter(X_test_df[:,4], y_test_df[:,2], label = 'Test Data', alpha = 0.05)
plt.scatter(X_test_df[:,4], y_pred_df[:,2], label = 'Model Prediction', alpha = 0.05)
plt.xlabel('Wall Shear Rate (s^-1)')
plt.ylabel('m')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()
